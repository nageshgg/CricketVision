# %%
# !pip install ultralytics
# %pip install roboflow

# %%
#Get dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HO5KiLDbYILIOgytrfZd")
project = rf.workspace("computer-vision-d3h0p").project("cricket-ball-segmentation")
version = project.version(5)
dataset = version.download("yolov8-obb")

# %%
dataset.location

# %%
import shutil

shutil.move('Cricket-Pitch-7/test', 'Cricket-Pitch-7/Cricket-Pitch-7/test')

# %%
shutil.move('Cricket-Pitch-7/train', 'Cricket-Pitch-7/Cricket-Pitch-7/train')

# %%
shutil.move('Cricket-Pitch-7/valid', 'Cricket-Pitch-7/Cricket-Pitch-7/valid')

# %%
# traning

# %%
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=30 imgsz=640
# Out:
# ...
#   0%|          | 0.00/131M [00:00<?, ?B/s]
#   0%|          | 256k/131M [00:00<01:14, 1.82MB/s]
#   0%|          | 512k/131M [00:00<01:17, 1.75MB/s]
#   1%|          | 768k/131M [00:00<01:28, 1.54MB/s]
#   1%|          | 1.00M/131M [00:00<01:24, 1.60MB/s]
#   1%|          | 1.25M/131M [00:00<01:33, 1.45MB/s]
#   1%|          | 1.50M/131M [00:01<01:31, 1.48MB/s]
#   1%|▏         | 1.75M/131M [00:01<01:39, 1.36MB/s]
#   2%|▏         | 2.00M/131M [00:01<01:39, 1.36MB/s]
#   2%|▏         | 2.25M/131M [00:01<01:50, 1.22MB/s]
#   2%|▏         | 2.38M/131M [00:01<01:50, 1.21MB/s]
#   2%|▏         | 2.50M/131M [00:01<01:59, 1.12MB/s]
#   2%|▏         | 2.62M/131M [00:02<02:06, 1.06MB/s]
#   2%|▏         | 2.75M/131M [00:02<02:14, 998kB/s]
#   2%|▏         | 2.88M/131M [00:02<02:16, 977kB/s]
#   2%|▏         | 3.00M/131M [00:02<02:13, 999kB/s]
#   2%|▏         | 3.12M/131M [00:02<02:14, 994kB/s]
#   2%|▏         | 3.25M/131M [00:02<02:08, 1.04MB/s]
# ...
